# %% [markdown]
# # Quantum Optimal Control through Reinforcement Learning using TD3 on fidelity
# ### Preparation of the 3 qubit Greenberger–Horne–Zeilinger state (GHZ state)
#
# In this notebook we address the task of creating the GHZ state $\frac{|000\rangle +|111\rangle}{\sqrt{2}}$ by optimising on the fidelity

# %%
import numpy as np
from stable_baselines3.common.vec_env import DummyVecEnv
import torch
from matplotlib import pyplot as plt

from qiskit import QuantumCircuit, transpile, assemble
from qiskit_aer import Aer
import numpy as np
import qiskit.quantum_info as qi
from math import pi
import math
from qiskit.quantum_info import Statevector, Operator,  DensityMatrix, state_fidelity
import itertools
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import seaborn as sns
import sys
sys.path.insert(1, '../src/')
from utils.functions import *
from models.models_rl import *

import random

random.seed(10)

# %% [markdown]
# In this cell, we define the quantum circuit designed to prepare the target GHZ state. You can also modify the target state and the initial state directly within this cell, allowing for flexibility in the setup. <br />

# %%
def create_controlled_ghz_circuit(thetas, initial_state):
  
    circ = QuantumCircuit(3)
    # Initialize qubits with the specified state
    circ.initialize(initial_state, [0,1,2])
    
    circ.ry(thetas[0,0], 0)
    circ.ry(thetas[0,1], 1)
    circ.ry(thetas[0,2], 2)
    circ.cx(0, 1)
    circ.cx(0, 2)
    circ.rx(thetas[0,3], 0)
    circ.rx(thetas[0,4], 1)
    circ.rx(thetas[0,5], 2)

    return circ
target_state = np.array([1 , 0, 0, 0, 0, 0, 0, 1])/np.sqrt(2)
initial_state = np.array([1, 0, 0, 0, 0, 0, 0, 0])
n_thetas = 6 #Number of parameters

ghz_visualization = create_controlled_ghz_circuit(np.zeros(n_thetas)[np.newaxis,:],initial_state)
ghz_visualization.draw('mpl')

# %% [markdown]
# We define the function to optimise

# %%
ghz_contr_circuit = create_controlled_ghz_circuit
def target_function(new_sample):
    _, new_fid_real, _ = get_expectation_values(ghz_contr_circuit, new_sample[np.newaxis,:],initial_state, target_state) #Get the real values

    return -new_fid_real

# %%
# Train the model
n_total_timesteps = 200
n_run = 10

params = {'lr': 0.0000001,
          'batch_size':5,
          'gamma':0.99,  
          'n_run':n_run,
          'n_total_timesteps': n_total_timesteps,
          'noise_std':0.01  ,
           'n_epochs': 20,
          }

metrics = {
    'best_fidelity_runs': np.zeros(n_run),
    'history_best_fidelity_runs': np.zeros((n_run, n_total_timesteps)),
    'value_losses_runs':np.zeros((n_run,n_total_timesteps)),
    'best_thetas_runs': np.zeros((n_run,n_thetas))
    }


for iter_run in range(n_run):
    print('run',iter_run+1)
    # Create the environment
    env = DummyVecEnv([lambda: OptimizationEnv(target_function=target_function, num_thetas=n_thetas)])
    metrics_callback = MetricsCallback()

   # Define the noise for exploration used in TD3
    n_actions = env.action_space.shape[-1]
    action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=params['noise_std']* np.ones(n_actions))

    # Create the model
    model = TD3(
        CustomTD3Policy, 
        env,
        action_noise=action_noise,
        verbose=1,
        learning_rate=params['lr'],  
        batch_size=params['batch_size'],  # Minibatch size for each gradient update
        gamma=params['gamma'],  # Discount factor
    )


    model.learn(total_timesteps=n_total_timesteps, callback=metrics_callback )

    X_train = np.array(env.envs[0].states) #Thetas
    y_train = np.abs(env.envs[0].rewards) #Fidelity
    best_thetas = env.envs[0].best_thetas
    best_fidelity = env.envs[0].best_value

    metrics['best_fidelity_runs'][iter_run] = np.abs((env.envs[0]).history[-1]) 
    metrics['history_best_fidelity_runs'][iter_run,:] = np.abs(env.envs[0].history)
    metrics['value_losses_runs'][iter_run] = metrics_callback.value_losses
    metrics['best_thetas_runs'][iter_run,:] = best_thetas
# Out:
# run 1
# Using cpu device
# ---------------------------
# | time/              |    |
# |    episodes        | 4  |
# |    fps             | 32 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 4  |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 8  |
# |    fps             | 34 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 8  |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 12 |
# |    fps             | 32 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 12 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 16 |
# |    fps             | 33 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 16 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 20 |
# |    fps             | 33 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 20 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 24 |
# |    fps             | 33 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 24 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 28 |
# |    fps             | 34 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 28 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 32 |
# |    fps             | 34 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 32 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 36 |
# |    fps             | 33 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 36 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 40 |
# |    fps             | 33 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 40 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 44 |
# |    fps             | 34 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 44 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 48 |
# |    fps             | 34 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 48 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 52 |
# |    fps             | 34 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 52 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 56 |
# |    fps             | 34 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 56 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 60 |
# |    fps             | 34 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 60 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 64 |
# |    fps             | 34 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 64 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 68 |
# |    fps             | 34 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 68 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 72 |
# |    fps             | 34 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 72 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 76 |
# |    fps             | 34 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 76 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 80 |
# |    fps             | 34 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 80 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 84 |
# |    fps             | 33 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 84 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 88 |
# |    fps             | 33 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 88 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 92 |
# |    fps             | 33 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 92 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 96 |
# |    fps             | 33 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 96 |
# ---------------------------
# ----------------------------
# | time/              |     |
# |    episodes        | 100 |
# |    fps             | 32  |
# |    time_elapsed    | 3   |
# |    total_timesteps | 100 |
# ----------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 30       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 104      |
# | train/             |          |
# |    actor_loss      | -0.0144  |
# |    critic_loss     | 0.115    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 3        |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 28       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 108      |
# | train/             |          |
# |    actor_loss      | -0.0142  |
# |    critic_loss     | 0.0161   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 7        |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 26       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 112      |
# | train/             |          |
# |    actor_loss      | -0.00986 |
# |    critic_loss     | 0.109    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 11       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 26       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 116      |
# | train/             |          |
# |    actor_loss      | -0.0116  |
# |    critic_loss     | 0.0514   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 15       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 25       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 120      |
# | train/             |          |
# |    actor_loss      | -0.00452 |
# |    critic_loss     | 0.0874   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 19       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 25       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 124      |
# | train/             |          |
# |    actor_loss      | -0.0109  |
# |    critic_loss     | 0.0978   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 23       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 25       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 128      |
# | train/             |          |
# |    actor_loss      | -0.0101  |
# |    critic_loss     | 0.2      |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 27       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 25       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 132      |
# | train/             |          |
# |    actor_loss      | -0.00624 |
# |    critic_loss     | 0.0977   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 31       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 25       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 136      |
# | train/             |          |
# |    actor_loss      | -0.0081  |
# |    critic_loss     | 0.0518   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 35       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 25       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 140      |
# | train/             |          |
# |    actor_loss      | -0.0111  |
# |    critic_loss     | 0.00977  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 39       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 25       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 144      |
# | train/             |          |
# |    actor_loss      | -0.0119  |
# |    critic_loss     | 0.0163   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 43       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 25       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 148      |
# | train/             |          |
# |    actor_loss      | -0.00991 |
# |    critic_loss     | 0.0118   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 47       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 25       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 152      |
# | train/             |          |
# |    actor_loss      | -0.00867 |
# |    critic_loss     | 0.15     |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 51       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 25       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 156      |
# | train/             |          |
# |    actor_loss      | -0.00962 |
# |    critic_loss     | 0.00228  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 55       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 25       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 160      |
# | train/             |          |
# |    actor_loss      | -0.0139  |
# |    critic_loss     | 0.0305   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 59       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 25       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 164      |
# | train/             |          |
# |    actor_loss      | -0.0143  |
# |    critic_loss     | 0.0935   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 63       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 25       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 168      |
# | train/             |          |
# |    actor_loss      | 0.00488  |
# |    critic_loss     | 0.00214  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 67       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 25       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 172      |
# | train/             |          |
# |    actor_loss      | -0.00661 |
# |    critic_loss     | 0.206    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 71       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 25       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 176      |
# | train/             |          |
# |    actor_loss      | -0.0013  |
# |    critic_loss     | 0.0485   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 75       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 25       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 180      |
# | train/             |          |
# |    actor_loss      | 0.000863 |
# |    critic_loss     | 0.00698  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 79       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 24       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 184      |
# | train/             |          |
# |    actor_loss      | -0.00434 |
# |    critic_loss     | 0.0771   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 83       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 24       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 188      |
# | train/             |          |
# |    actor_loss      | 0.000751 |
# |    critic_loss     | 0.0656   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 87       |
# ---------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 192       |
# |    fps             | 24        |
# |    time_elapsed    | 7         |
# |    total_timesteps | 192       |
# | train/             |           |
# |    actor_loss      | -0.000435 |
# |    critic_loss     | 0.0712    |
# |    learning_rate   | 1e-07     |
# |    n_updates       | 91        |
# ----------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 24       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 196      |
# | train/             |          |
# |    actor_loss      | -0.00811 |
# |    critic_loss     | 0.0295   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 95       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 24       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | -0.0128  |
# |    critic_loss     | 0.0452   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 99       |
# ---------------------------------
# run 2
# Using cpu device
# ---------------------------
# | time/              |    |
# |    episodes        | 4  |
# |    fps             | 25 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 4  |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 8  |
# |    fps             | 19 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 8  |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 12 |
# |    fps             | 21 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 12 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 16 |
# |    fps             | 22 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 16 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 20 |
# |    fps             | 23 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 20 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 24 |
# |    fps             | 23 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 24 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 28 |
# |    fps             | 24 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 28 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 32 |
# |    fps             | 24 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 32 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 36 |
# |    fps             | 24 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 36 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 40 |
# |    fps             | 25 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 40 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 44 |
# |    fps             | 25 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 44 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 48 |
# |    fps             | 26 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 48 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 52 |
# |    fps             | 26 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 52 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 56 |
# |    fps             | 26 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 56 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 60 |
# |    fps             | 26 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 60 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 64 |
# |    fps             | 26 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 64 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 68 |
# |    fps             | 26 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 68 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 72 |
# |    fps             | 26 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 72 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 76 |
# |    fps             | 26 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 76 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 80 |
# |    fps             | 26 |
# |    time_elapsed    | 3  |
# |    total_timesteps | 80 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 84 |
# |    fps             | 26 |
# |    time_elapsed    | 3  |
# |    total_timesteps | 84 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 88 |
# |    fps             | 26 |
# |    time_elapsed    | 3  |
# |    total_timesteps | 88 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 92 |
# |    fps             | 26 |
# |    time_elapsed    | 3  |
# |    total_timesteps | 92 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 96 |
# |    fps             | 26 |
# |    time_elapsed    | 3  |
# |    total_timesteps | 96 |
# ---------------------------
# ----------------------------
# | time/              |     |
# |    episodes        | 100 |
# |    fps             | 26  |
# |    time_elapsed    | 3   |
# |    total_timesteps | 100 |
# ----------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 26       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 104      |
# | train/             |          |
# |    actor_loss      | -0.129   |
# |    critic_loss     | 0.233    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 3        |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 26       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 108      |
# | train/             |          |
# |    actor_loss      | -0.112   |
# |    critic_loss     | 0.143    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 7        |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 26       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 112      |
# | train/             |          |
# |    actor_loss      | -0.118   |
# |    critic_loss     | 0.031    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 11       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 25       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 116      |
# | train/             |          |
# |    actor_loss      | -0.118   |
# |    critic_loss     | 0.165    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 15       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 25       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 120      |
# | train/             |          |
# |    actor_loss      | -0.141   |
# |    critic_loss     | 0.105    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 19       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 25       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 124      |
# | train/             |          |
# |    actor_loss      | -0.14    |
# |    critic_loss     | 0.0288   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 23       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 25       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 128      |
# | train/             |          |
# |    actor_loss      | -0.127   |
# |    critic_loss     | 0.134    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 27       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 24       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 132      |
# | train/             |          |
# |    actor_loss      | -0.121   |
# |    critic_loss     | 0.111    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 31       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 24       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 136      |
# | train/             |          |
# |    actor_loss      | -0.126   |
# |    critic_loss     | 0.139    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 35       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 23       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 140      |
# | train/             |          |
# |    actor_loss      | -0.129   |
# |    critic_loss     | 0.0373   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 39       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 23       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 144      |
# | train/             |          |
# |    actor_loss      | -0.12    |
# |    critic_loss     | 0.174    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 43       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 23       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 148      |
# | train/             |          |
# |    actor_loss      | -0.125   |
# |    critic_loss     | 0.0633   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 47       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 23       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 152      |
# | train/             |          |
# |    actor_loss      | -0.134   |
# |    critic_loss     | 0.192    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 51       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 23       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 156      |
# | train/             |          |
# |    actor_loss      | -0.112   |
# |    critic_loss     | 0.0301   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 55       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 23       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 160      |
# | train/             |          |
# |    actor_loss      | -0.13    |
# |    critic_loss     | 0.0202   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 59       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 23       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 164      |
# | train/             |          |
# |    actor_loss      | -0.131   |
# |    critic_loss     | 0.112    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 63       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 23       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 168      |
# | train/             |          |
# |    actor_loss      | -0.113   |
# |    critic_loss     | 0.117    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 67       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 23       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 172      |
# | train/             |          |
# |    actor_loss      | -0.13    |
# |    critic_loss     | 0.0416   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 71       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 23       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 176      |
# | train/             |          |
# |    actor_loss      | -0.126   |
# |    critic_loss     | 0.0248   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 75       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 23       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 180      |
# | train/             |          |
# |    actor_loss      | -0.119   |
# |    critic_loss     | 0.144    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 79       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 23       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 184      |
# | train/             |          |
# |    actor_loss      | -0.121   |
# |    critic_loss     | 0.155    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 83       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 23       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 188      |
# | train/             |          |
# |    actor_loss      | -0.12    |
# |    critic_loss     | 0.0893   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 87       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 22       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 192      |
# | train/             |          |
# |    actor_loss      | -0.122   |
# |    critic_loss     | 0.0376   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 91       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 23       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 196      |
# | train/             |          |
# |    actor_loss      | -0.131   |
# |    critic_loss     | 0.0306   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 95       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 23       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | -0.121   |
# |    critic_loss     | 0.146    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 99       |
# ---------------------------------
# run 3
# Using cpu device
# ---------------------------
# | time/              |    |
# |    episodes        | 4  |
# |    fps             | 27 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 4  |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 8  |
# |    fps             | 28 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 8  |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 12 |
# |    fps             | 29 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 12 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 16 |
# |    fps             | 29 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 16 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 20 |
# |    fps             | 30 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 20 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 24 |
# |    fps             | 30 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 24 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 28 |
# |    fps             | 30 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 28 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 32 |
# |    fps             | 30 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 32 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 36 |
# |    fps             | 31 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 36 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 40 |
# |    fps             | 31 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 40 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 44 |
# |    fps             | 31 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 44 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 48 |
# |    fps             | 30 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 48 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 52 |
# |    fps             | 30 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 52 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 56 |
# |    fps             | 28 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 56 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 60 |
# |    fps             | 28 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 60 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 64 |
# |    fps             | 28 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 64 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 68 |
# |    fps             | 28 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 68 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 72 |
# |    fps             | 28 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 72 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 76 |
# |    fps             | 28 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 76 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 80 |
# |    fps             | 27 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 80 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 84 |
# |    fps             | 27 |
# |    time_elapsed    | 3  |
# |    total_timesteps | 84 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 88 |
# |    fps             | 27 |
# |    time_elapsed    | 3  |
# |    total_timesteps | 88 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 92 |
# |    fps             | 27 |
# |    time_elapsed    | 3  |
# |    total_timesteps | 92 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 96 |
# |    fps             | 27 |
# |    time_elapsed    | 3  |
# |    total_timesteps | 96 |
# ---------------------------
# ----------------------------
# | time/              |     |
# |    episodes        | 100 |
# |    fps             | 27  |
# |    time_elapsed    | 3   |
# |    total_timesteps | 100 |
# ----------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 27       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 104      |
# | train/             |          |
# |    actor_loss      | -0.07    |
# |    critic_loss     | 0.17     |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 3        |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 26       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 108      |
# | train/             |          |
# |    actor_loss      | -0.079   |
# |    critic_loss     | 0.156    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 7        |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 26       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 112      |
# | train/             |          |
# |    actor_loss      | -0.0971  |
# |    critic_loss     | 0.249    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 11       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 25       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 116      |
# | train/             |          |
# |    actor_loss      | -0.0851  |
# |    critic_loss     | 0.251    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 15       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 25       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 120      |
# | train/             |          |
# |    actor_loss      | -0.0843  |
# |    critic_loss     | 0.254    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 19       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 25       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 124      |
# | train/             |          |
# |    actor_loss      | -0.11    |
# |    critic_loss     | 0.182    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 23       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 24       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 128      |
# | train/             |          |
# |    actor_loss      | -0.0648  |
# |    critic_loss     | 0.103    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 27       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 24       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 132      |
# | train/             |          |
# |    actor_loss      | -0.0889  |
# |    critic_loss     | 0.146    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 31       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 24       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 136      |
# | train/             |          |
# |    actor_loss      | -0.0843  |
# |    critic_loss     | 0.172    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 35       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 24       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 140      |
# | train/             |          |
# |    actor_loss      | -0.0676  |
# |    critic_loss     | 0.148    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 39       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 24       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 144      |
# | train/             |          |
# |    actor_loss      | -0.0711  |
# |    critic_loss     | 0.0834   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 43       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 24       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 148      |
# | train/             |          |
# |    actor_loss      | -0.0905  |
# |    critic_loss     | 0.119    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 47       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 24       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 152      |
# | train/             |          |
# |    actor_loss      | -0.0687  |
# |    critic_loss     | 0.0861   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 51       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 24       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 156      |
# | train/             |          |
# |    actor_loss      | -0.0762  |
# |    critic_loss     | 0.061    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 55       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 24       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 160      |
# | train/             |          |
# |    actor_loss      | -0.0882  |
# |    critic_loss     | 0.191    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 59       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 24       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 164      |
# | train/             |          |
# |    actor_loss      | -0.0812  |
# |    critic_loss     | 0.11     |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 63       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 24       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 168      |
# | train/             |          |
# |    actor_loss      | -0.0579  |
# |    critic_loss     | 0.0775   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 67       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 24       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 172      |
# | train/             |          |
# |    actor_loss      | -0.0753  |
# |    critic_loss     | 0.109    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 71       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 24       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 176      |
# | train/             |          |
# |    actor_loss      | -0.0813  |
# |    critic_loss     | 0.0386   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 75       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 23       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 180      |
# | train/             |          |
# |    actor_loss      | -0.0657  |
# |    critic_loss     | 0.126    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 79       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 23       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 184      |
# | train/             |          |
# |    actor_loss      | -0.0505  |
# |    critic_loss     | 0.0492   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 83       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 23       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 188      |
# | train/             |          |
# |    actor_loss      | -0.11    |
# |    critic_loss     | 0.162    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 87       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 23       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 192      |
# | train/             |          |
# |    actor_loss      | -0.0568  |
# |    critic_loss     | 0.15     |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 91       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 23       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 196      |
# | train/             |          |
# |    actor_loss      | -0.1     |
# |    critic_loss     | 0.165    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 95       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 23       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | -0.0729  |
# |    critic_loss     | 0.0472   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 99       |
# ---------------------------------
# run 4
# Using cpu device
# ---------------------------
# | time/              |    |
# |    episodes        | 4  |
# |    fps             | 29 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 4  |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 8  |
# |    fps             | 29 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 8  |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 12 |
# |    fps             | 29 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 12 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 16 |
# |    fps             | 29 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 16 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 20 |
# |    fps             | 29 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 20 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 24 |
# |    fps             | 27 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 24 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 28 |
# |    fps             | 26 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 28 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 32 |
# |    fps             | 26 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 32 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 36 |
# |    fps             | 26 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 36 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 40 |
# |    fps             | 26 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 40 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 44 |
# |    fps             | 26 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 44 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 48 |
# |    fps             | 27 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 48 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 52 |
# |    fps             | 27 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 52 |
# ---------------------------
# ...
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 22       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 196      |
# | train/             |          |
# |    actor_loss      | 0.0301   |
# |    critic_loss     | 0.0591   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 95       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 22       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | 0.0197   |
# |    critic_loss     | 0.0187   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 99       |
# ---------------------------------
# run 10
# Using cpu device
# ---------------------------
# | time/              |    |
# |    episodes        | 4  |
# |    fps             | 23 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 4  |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 8  |
# |    fps             | 25 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 8  |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 12 |
# |    fps             | 20 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 12 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 16 |
# |    fps             | 22 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 16 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 20 |
# |    fps             | 22 |
# |    time_elapsed    | 0  |
# |    total_timesteps | 20 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 24 |
# |    fps             | 23 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 24 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 28 |
# |    fps             | 24 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 28 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 32 |
# |    fps             | 24 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 32 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 36 |
# |    fps             | 25 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 36 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 40 |
# |    fps             | 25 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 40 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 44 |
# |    fps             | 25 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 44 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 48 |
# |    fps             | 25 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 48 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 52 |
# |    fps             | 26 |
# |    time_elapsed    | 1  |
# |    total_timesteps | 52 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 56 |
# |    fps             | 26 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 56 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 60 |
# |    fps             | 26 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 60 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 64 |
# |    fps             | 26 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 64 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 68 |
# |    fps             | 26 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 68 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 72 |
# |    fps             | 26 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 72 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 76 |
# |    fps             | 26 |
# |    time_elapsed    | 2  |
# |    total_timesteps | 76 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 80 |
# |    fps             | 26 |
# |    time_elapsed    | 3  |
# |    total_timesteps | 80 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 84 |
# |    fps             | 26 |
# |    time_elapsed    | 3  |
# |    total_timesteps | 84 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 88 |
# |    fps             | 26 |
# |    time_elapsed    | 3  |
# |    total_timesteps | 88 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 92 |
# |    fps             | 26 |
# |    time_elapsed    | 3  |
# |    total_timesteps | 92 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 96 |
# |    fps             | 26 |
# |    time_elapsed    | 3  |
# |    total_timesteps | 96 |
# ---------------------------
# ----------------------------
# | time/              |     |
# |    episodes        | 100 |
# |    fps             | 26  |
# |    time_elapsed    | 3   |
# |    total_timesteps | 100 |
# ----------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 26       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 104      |
# | train/             |          |
# |    actor_loss      | -0.025   |
# |    critic_loss     | 0.0341   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 3        |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 26       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 108      |
# | train/             |          |
# |    actor_loss      | -0.00946 |
# |    critic_loss     | 0.0233   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 7        |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 26       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 112      |
# | train/             |          |
# |    actor_loss      | 2.04e-05 |
# |    critic_loss     | 0.158    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 11       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 26       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 116      |
# | train/             |          |
# |    actor_loss      | -0.00478 |
# |    critic_loss     | 0.0198   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 15       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 25       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 120      |
# | train/             |          |
# |    actor_loss      | -0.0232  |
# |    critic_loss     | 0.0097   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 19       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 25       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 124      |
# | train/             |          |
# |    actor_loss      | -0.0177  |
# |    critic_loss     | 0.0198   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 23       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 25       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 128      |
# | train/             |          |
# |    actor_loss      | -0.0201  |
# |    critic_loss     | 0.0114   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 27       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 25       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 132      |
# | train/             |          |
# |    actor_loss      | -0.0217  |
# |    critic_loss     | 0.00822  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 31       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 24       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 136      |
# | train/             |          |
# |    actor_loss      | -0.00784 |
# |    critic_loss     | 0.00364  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 35       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 24       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 140      |
# | train/             |          |
# |    actor_loss      | -0.0174  |
# |    critic_loss     | 0.024    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 39       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 24       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 144      |
# | train/             |          |
# |    actor_loss      | 6.7e-05  |
# |    critic_loss     | 0.0477   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 43       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 24       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 148      |
# | train/             |          |
# |    actor_loss      | -0.0206  |
# |    critic_loss     | 0.0321   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 47       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 24       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 152      |
# | train/             |          |
# |    actor_loss      | 0.000226 |
# |    critic_loss     | 0.00321  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 51       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 23       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 156      |
# | train/             |          |
# |    actor_loss      | -0.0257  |
# |    critic_loss     | 0.0247   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 55       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 23       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 160      |
# | train/             |          |
# |    actor_loss      | -0.00888 |
# |    critic_loss     | 0.0167   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 59       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 23       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 164      |
# | train/             |          |
# |    actor_loss      | -0.00698 |
# |    critic_loss     | 0.1      |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 63       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 23       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 168      |
# | train/             |          |
# |    actor_loss      | -0.0217  |
# |    critic_loss     | 0.00317  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 67       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 23       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 172      |
# | train/             |          |
# |    actor_loss      | -0.0178  |
# |    critic_loss     | 0.0121   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 71       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 23       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 176      |
# | train/             |          |
# |    actor_loss      | -0.0384  |
# |    critic_loss     | 0.0281   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 75       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 23       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 180      |
# | train/             |          |
# |    actor_loss      | -0.0237  |
# |    critic_loss     | 0.0318   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 79       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 23       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 184      |
# | train/             |          |
# |    actor_loss      | -0.0217  |
# |    critic_loss     | 0.0151   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 83       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 23       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 188      |
# | train/             |          |
# |    actor_loss      | -0.00914 |
# |    critic_loss     | 0.0267   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 87       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 23       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 192      |
# | train/             |          |
# |    actor_loss      | -0.00792 |
# |    critic_loss     | 0.0108   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 91       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 23       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 196      |
# | train/             |          |
# |    actor_loss      | -0.00871 |
# |    critic_loss     | 0.0029   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 95       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 23       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | -0.0217  |
# |    critic_loss     | 0.00483  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 99       |
# ---------------------------------

# %%
plt.plot(np.arange(n_total_timesteps),1-np.mean(metrics['history_best_fidelity_runs'],0),'-o', linewidth=1.3)
plt.ylabel('Infidelity')
plt.xlabel('Iteration')
plt.yscale('log')
plt.title('GHZ state infidelity during RL TD3', size=14)
plt.show()
print('Mean best infidelity: ', 1-np.mean(metrics['best_fidelity_runs']))
# Out:
# Mean best infidelity:  0.4402561779849734

# %%
# Test the model
obs = env.reset()
action, _ = model.predict(obs, deterministic=True)
print(f'Best angles: {action}')
print(f'Target function value: {1 - np.abs(target_function(action[0]))}')
# Out:
# Best angles: [[2.722209  3.0237653 3.0358064 3.3826127 3.4962142 3.306935 ]]
# Target function value: 0.9877099792661438

# %%
data_plot = {   'history_best_fidelity_runs':metrics['history_best_fidelity_runs'],
                'best_thetas_runs': metrics['best_thetas_runs'],
                'best_fidelity_runs':metrics['best_fidelity_runs'],
            } 
if True:
    with open("../results/qoc/results_3ghz_td3.json", "w") as outfile: 
        json.dump(data_plot, outfile, cls=CustomEncoder)

# %% [markdown]
# Optionally: Track metrics and parameters in MLflow

# %%
import mlflow
#Metrics resume
metrics_reg= {
    'mean_infidelity_runs': 1- np.mean(metrics['best_fidelity_runs']),
    'std_infidelity_runs': np.std(metrics['best_fidelity_runs']),
        }

params['size_final_dataset'] = y_train.shape[0]


mlflow.set_tracking_uri(uri="http://127.0.0.1:8080")
mlflow.set_experiment("QOC_3GHZ")

with mlflow.start_run(run_name='3GHZ_RL_TD3'):

    mlflow.log_params(params)
    mlflow.log_metrics(metrics_reg)
# Out:
# 2024/09/21 11:22:03 INFO mlflow.tracking._tracking_service.client: 🏃 View run GHZ_RL_TD3 at: http://127.0.0.1:8080/#/experiments/126759745047636218/runs/f63c3288f00049a0843471042ddaf86f.
# 2024/09/21 11:22:03 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:8080/#/experiments/126759745047636218.
