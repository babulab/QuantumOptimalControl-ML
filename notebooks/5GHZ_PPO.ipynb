# %% [markdown]
# # Quantum Optimal Control through Reinforcement Learning using Proximal Policy Optimisation on fidelity
# ### Preparation of the 5 qubit Greenberger–Horne–Zeilinger state (GHZ state)
#
# In this notebook we address the task of creating the GHZ state $\frac{|00000\rangle +|11111\rangle}{\sqrt{2}}$ by optimising on the fidelity

# %%
import numpy as np
from stable_baselines3.common.vec_env import DummyVecEnv
import torch
from matplotlib import pyplot as plt

from qiskit import QuantumCircuit, transpile, assemble
from qiskit_aer import Aer
import numpy as np
import qiskit.quantum_info as qi
from math import pi
import math
import matplotlib.pylab as plt
from qiskit.quantum_info import Statevector, Operator,  DensityMatrix,state_fidelity
import itertools
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import seaborn as sns
import sys
sys.path.insert(1, '../src/')
from utils.functions import *
from models.models_rl import *

import random

random.seed(10)

# %% [markdown]
# In this cell, we define the quantum circuit designed to prepare the target GHZ state. You can also modify the target state and the initial state directly within this cell, allowing for flexibility in the setup. <br />

# %%
def create_controlled_ghz_circuit(thetas, initial_state):
  

    circ = QuantumCircuit(num_qubits)
    circ.initialize(initial_state)

    for i in range(0,num_qubits):
        circ.ry(thetas[0,i], i)

    for i in range(1,num_qubits):
        circ.cx(0, i)

    for i in range(0,num_qubits):
        circ.rx(thetas[0,i], i)

    return circ


num_qubits = 5
target_state = np.zeros(2**num_qubits)
target_state[0], target_state[-1] = 1, 1
target_state = target_state/np.sqrt(2) 

initial_state = np.zeros(2**num_qubits)
initial_state[0] = 1
n_thetas = 10 #Number of parameters


ghz_visualization = create_controlled_ghz_circuit(np.zeros(n_thetas)[np.newaxis,:],initial_state)

ghz_visualization.draw('mpl')

# %% [markdown]
# We define the function to optimise

# %%
ghz_contr_circuit = create_controlled_ghz_circuit
def target_function(new_sample):
    _, new_fid_real, _ = get_expectation_values(ghz_contr_circuit, new_sample[np.newaxis,:],initial_state, target_state) #Get the real values

    return -new_fid_real

# %% [markdown]
# We set up our experiment, and calculate metrics of interest.

# %%
# Train the model
n_total_timesteps = 200
n_run = 10

#it should be:
#n_steps>batch_size

params = {'lr': 0.000001,
          'n_steps': 20,
          'batch_size':10,
          'gae_lambda': 0.95,
          'gamma':0.99,  
          'ent_coef':0.01,
          'clip_range':0.3,
          'n_run':n_run,
          'n_total_timesteps': n_total_timesteps,
          'n_epochs': 20
          }

metrics = {
    'best_fidelity_runs': np.zeros(n_run),
    'history_best_fidelity_runs': np.zeros((n_run, n_total_timesteps)),
    'value_losses_runs':np.zeros((n_run,n_total_timesteps)),
    'best_thetas_runs': np.zeros((n_run,n_thetas))
    }


for iter_run in range(n_run):
    print('run',iter_run+1)
    # Create the environment
    env = DummyVecEnv([lambda: OptimizationEnv(target_function, n_thetas)])
    metrics_callback = MetricsCallback()
    # Create the model
    model = PPO(
        CustomActorCriticPolicy, 
        env,
        verbose=1,
        learning_rate=params['lr'],  # Default learning rate; can be tuned further
        n_steps=params['n_steps'],  # Number of steps to run for each environment per update
        batch_size=params['batch_size'],  # Minibatch size for each gradient update
        gae_lambda=params['gae_lambda'],  # Lambda for GAE
        gamma=params['gamma'],  # Discount factor
        ent_coef=params['ent_coef'],  # Entropy coefficient for exploration
        clip_range=params['clip_range'],  # Clipping range for PPO
        n_epochs = params['n_epochs']
    )


    #model = PPO('MlpPolicy', env, n_steps=10)

    model.learn(total_timesteps=n_total_timesteps, callback=metrics_callback )
   
    X_train = np.array(env.envs[0].states) #Thetas
    y_train = np.abs(env.envs[0].rewards) #Fidelity
    best_thetas = env.envs[0].best_thetas
    best_fidelity = env.envs[0].best_value

    metrics['best_fidelity_runs'][iter_run] = np.abs((env.envs[0]).history[-1]) 
    metrics['history_best_fidelity_runs'][iter_run,:] = np.abs(env.envs[0].history)
    metrics['value_losses_runs'][iter_run] = metrics_callback.value_losses
    metrics['best_thetas_runs'][iter_run,:] = best_thetas
# Out:
# run 1
# Using cpu device
# ---------------------------
# | time/              |    |
# |    fps             | 7  |
# |    iterations      | 1  |
# |    time_elapsed    | 2  |
# |    total_timesteps | 20 |
# ---------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 40          |
# | train/                  |             |
# |    approx_kl            | 7.18236e-07 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -14.2       |
# |    explained_variance   | -19.8       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 2.51        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.000382   |
# |    std                  | 1           |
# |    value_loss           | 4.62        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 3            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 60           |
# | train/                  |              |
# |    approx_kl            | 2.256036e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -14.2        |
# |    explained_variance   | -40          |
# |    learning_rate        | 1e-06        |
# |    loss                 | 2.05         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000569    |
# |    std                  | 1            |
# |    value_loss           | 4.8          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 4             |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 80            |
# | train/                  |               |
# |    approx_kl            | 1.0073186e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -12.3         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 2.64          |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000352     |
# |    std                  | 1             |
# |    value_loss           | 5.83          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 5             |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 100           |
# | train/                  |               |
# |    approx_kl            | 1.2338162e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -23.4         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 2.32          |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000485     |
# |    std                  | 1             |
# |    value_loss           | 5.34          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 6             |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 120           |
# | train/                  |               |
# |    approx_kl            | 1.6093254e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -63.5         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 2.71          |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000527     |
# |    std                  | 1             |
# |    value_loss           | 6.18          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 7            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 140          |
# | train/                  |              |
# |    approx_kl            | 7.659197e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -14.2        |
# |    explained_variance   | -21          |
# |    learning_rate        | 1e-06        |
# |    loss                 | 3.32         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000394    |
# |    std                  | 1            |
# |    value_loss           | 5.81         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 8             |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 160           |
# | train/                  |               |
# |    approx_kl            | 1.1593104e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -29.5         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.52          |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000473     |
# |    std                  | 1             |
# |    value_loss           | 4.97          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 9           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 180         |
# | train/                  |             |
# |    approx_kl            | 2.56896e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -14.2       |
# |    explained_variance   | -35.9       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 2.93        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.000537   |
# |    std                  | 1           |
# |    value_loss           | 6.81        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 10           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 200          |
# | train/                  |              |
# |    approx_kl            | 2.706051e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -14.2        |
# |    explained_variance   | -38          |
# |    learning_rate        | 1e-06        |
# |    loss                 | 2.28         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000741    |
# |    std                  | 1            |
# |    value_loss           | 4.49         |
# ------------------------------------------
# run 2
# Using cpu device
# ---------------------------
# | time/              |    |
# |    fps             | 6  |
# |    iterations      | 1  |
# |    time_elapsed    | 3  |
# |    total_timesteps | 20 |
# ---------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 40           |
# | train/                  |              |
# |    approx_kl            | 3.963709e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -14.2        |
# |    explained_variance   | -7.36        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.636        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000892    |
# |    std                  | 1            |
# |    value_loss           | 1.6          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 3             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 60            |
# | train/                  |               |
# |    approx_kl            | 3.7342309e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -10.3         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.269         |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00077      |
# |    std                  | 1             |
# |    value_loss           | 1.14          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 4             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 80            |
# | train/                  |               |
# |    approx_kl            | 1.5079975e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -32.9         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.52          |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000401     |
# |    std                  | 1             |
# |    value_loss           | 3.07          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 5            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 100          |
# | train/                  |              |
# |    approx_kl            | 2.029538e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -14.2        |
# |    explained_variance   | -13.2        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.976        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00058     |
# |    std                  | 1            |
# |    value_loss           | 1.92         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 6             |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 120           |
# | train/                  |               |
# |    approx_kl            | 3.2752753e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -14.1         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.725         |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000713     |
# |    std                  | 1             |
# |    value_loss           | 1.96          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 7             |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 140           |
# | train/                  |               |
# |    approx_kl            | 2.5808813e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -5.99         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.468         |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000496     |
# |    std                  | 1             |
# |    value_loss           | 1.18          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 8             |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 160           |
# | train/                  |               |
# |    approx_kl            | 1.4871359e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -5.27         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.73          |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000537     |
# |    std                  | 1             |
# |    value_loss           | 2             |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 9             |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 180           |
# | train/                  |               |
# |    approx_kl            | 1.4483928e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -6.51         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.401         |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000439     |
# |    std                  | 1             |
# |    value_loss           | 1.69          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 10           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 200          |
# | train/                  |              |
# |    approx_kl            | 8.493662e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -14.2        |
# |    explained_variance   | -21.1        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 1.77         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000324    |
# |    std                  | 1            |
# |    value_loss           | 2.74         |
# ------------------------------------------
# run 3
# Using cpu device
# ---------------------------
# | time/              |    |
# |    fps             | 6  |
# |    iterations      | 1  |
# |    time_elapsed    | 3  |
# |    total_timesteps | 20 |
# ---------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 2             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 40            |
# | train/                  |               |
# |    approx_kl            | 1.5884639e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -13.9         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.94          |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000477     |
# |    std                  | 1             |
# |    value_loss           | 4.68          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 3             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 60            |
# | train/                  |               |
# |    approx_kl            | 8.8214875e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -14           |
# |    learning_rate        | 1e-06         |
# |    loss                 | 2.2           |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000371     |
# |    std                  | 1             |
# |    value_loss           | 5.11          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 4             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 80            |
# | train/                  |               |
# |    approx_kl            | 1.3023614e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -8.36         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 2.75          |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000461     |
# |    std                  | 1             |
# |    value_loss           | 5.36          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 5            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 100          |
# | train/                  |              |
# |    approx_kl            | 1.385808e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -14.2        |
# |    explained_variance   | -8.57        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 2.24         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000529    |
# |    std                  | 1            |
# |    value_loss           | 5.18         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 6             |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 120           |
# | train/                  |               |
# |    approx_kl            | 2.7090312e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -12.2         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.48          |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000646     |
# |    std                  | 1             |
# |    value_loss           | 3.63          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 7             |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 140           |
# | train/                  |               |
# |    approx_kl            | 2.1576882e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -7.48         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 2.15          |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000542     |
# |    std                  | 1             |
# |    value_loss           | 3.88          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 8             |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 160           |
# | train/                  |               |
# |    approx_kl            | 1.0848046e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -8.3          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.64          |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000412     |
# |    std                  | 1             |
# |    value_loss           | 3.6           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 9            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 180          |
# | train/                  |              |
# |    approx_kl            | 4.708767e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -14.2        |
# |    explained_variance   | -8.75        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 1.39         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000274    |
# |    std                  | 1            |
# |    value_loss           | 4.31         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 10           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 200          |
# | train/                  |              |
# |    approx_kl            | 1.308322e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -14.2        |
# |    explained_variance   | -17.4        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 1.82         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000437    |
# |    std                  | 1            |
# |    value_loss           | 3.81         |
# ------------------------------------------
# run 4
# Using cpu device
# ---------------------------
# | time/              |    |
# |    fps             | 6  |
# |    iterations      | 1  |
# |    time_elapsed    | 3  |
# |    total_timesteps | 20 |
# ---------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 2             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 40            |
# | train/                  |               |
# |    approx_kl            | 6.0737134e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -16.9         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0554        |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00105      |
# |    std                  | 1             |
# |    value_loss           | 0.397         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 3             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 60            |
# | train/                  |               |
# |    approx_kl            | 1.2755394e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -28.1         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.167         |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000321     |
# |    std                  | 1             |
# |    value_loss           | 0.439         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 4             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 80            |
# | train/                  |               |
# |    approx_kl            | 1.4424324e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -14           |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0492        |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000449     |
# |    std                  | 1             |
# |    value_loss           | 0.354         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 5             |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 100           |
# | train/                  |               |
# |    approx_kl            | 1.6927719e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -17.3         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0135        |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000532     |
# |    std                  | 1             |
# |    value_loss           | 0.529         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 6             |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 120           |
# | train/                  |               |
# |    approx_kl            | 3.2037497e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -17.6         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0569        |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000781     |
# |    std                  | 1             |
# |    value_loss           | 0.418         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 7             |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 140           |
# | train/                  |               |
# |    approx_kl            | 7.2240828e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -17.6         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.11          |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.00108      |
# |    std                  | 1             |
# |    value_loss           | 0.437         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 8            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 160          |
# | train/                  |              |
# |    approx_kl            | 9.176135e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -14.2        |
# |    explained_variance   | -6.94        |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.085       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00109     |
# |    std                  | 1            |
# |    value_loss           | 0.124        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 9            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 180          |
# | train/                  |              |
# |    approx_kl            | 4.011393e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -14.2        |
# |    explained_variance   | -17.2        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0694       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000796    |
# |    std                  | 1            |
# |    value_loss           | 0.473        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 10            |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 200           |
# | train/                  |               |
# |    approx_kl            | 2.6762486e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -20.7         |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0161       |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000699     |
# |    std                  | 1             |
# |    value_loss           | 0.396         |
# -------------------------------------------
# run 5
# Using cpu device
# ---------------------------
# | time/              |    |
# |    fps             | 6  |
# |    iterations      | 1  |
# |    time_elapsed    | 3  |
# |    total_timesteps | 20 |
# ---------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 2             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 40            |
# | train/                  |               |
# |    approx_kl            | 3.5911798e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -11.5         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.241         |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000827     |
# |    std                  | 1             |
# |    value_loss           | 0.651         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 3             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 60            |
# | train/                  |               |
# |    approx_kl            | 3.0636788e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -8.12         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.471         |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000806     |
# |    std                  | 1             |
# |    value_loss           | 0.981         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 4             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 80            |
# | train/                  |               |
# |    approx_kl            | 4.0650366e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -18.1         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.372         |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000801     |
# |    std                  | 1             |
# |    value_loss           | 0.866         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 5             |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 100           |
# | train/                  |               |
# |    approx_kl            | 2.4408102e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -11.5         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.316         |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000652     |
# |    std                  | 1             |
# |    value_loss           | 0.904         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 6             |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 120           |
# | train/                  |               |
# |    approx_kl            | 8.2850454e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -7.07         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.277         |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000368     |
# |    std                  | 1             |
# |    value_loss           | 1.17          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 7             |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 140           |
# | train/                  |               |
# |    approx_kl            | 2.7030705e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -7.23         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.122         |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000605     |
# |    std                  | 1             |
# |    value_loss           | 0.49          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 8             |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 160           |
# | train/                  |               |
# |    approx_kl            | 4.8935412e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -13.4         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0909        |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000915     |
# |    std                  | 1             |
# |    value_loss           | 0.645         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 9             |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 180           |
# | train/                  |               |
# |    approx_kl            | 1.5825033e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -8            |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.181         |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000518     |
# |    std                  | 1             |
# |    value_loss           | 0.747         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 10            |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 200           |
# | train/                  |               |
# |    approx_kl            | 2.3543835e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -12.9         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.454         |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000611     |
# |    std                  | 1             |
# |    value_loss           | 0.761         |
# -------------------------------------------
# run 6
# Using cpu device
# ---------------------------
# | time/              |    |
# |    fps             | 6  |
# |    iterations      | 1  |
# |    time_elapsed    | 3  |
# |    total_timesteps | 20 |
# ---------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 2             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 40            |
# | train/                  |               |
# |    approx_kl            | 1.6957522e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -91.2         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.849         |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000676     |
# |    std                  | 1             |
# |    value_loss           | 2.24          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 3             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 60            |
# | train/                  |               |
# |    approx_kl            | 2.2351742e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -25.9         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.383         |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000515     |
# |    std                  | 1             |
# |    value_loss           | 2.24          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 4             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 80            |
# | train/                  |               |
# |    approx_kl            | 2.6464463e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -21.8         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.751         |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000753     |
# |    std                  | 1             |
# |    value_loss           | 1.58          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 5             |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 100           |
# | train/                  |               |
# |    approx_kl            | 1.3589859e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -30           |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.432         |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000433     |
# |    std                  | 1             |
# |    value_loss           | 1.63          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 6             |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 120           |
# | train/                  |               |
# |    approx_kl            | 1.3113022e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -15           |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.68          |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.00043      |
# |    std                  | 1             |
# |    value_loss           | 1.52          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 7             |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 140           |
# | train/                  |               |
# |    approx_kl            | 5.0961967e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -66           |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.754         |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000265     |
# |    std                  | 1             |
# |    value_loss           | 1.89          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 8            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 160          |
# | train/                  |              |
# |    approx_kl            | 1.782179e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -14.2        |
# |    explained_variance   | -19.8        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.688        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000633    |
# |    std                  | 1            |
# |    value_loss           | 1.9          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 9             |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 180           |
# | train/                  |               |
# |    approx_kl            | 4.5329334e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -14.3         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.34          |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.00091      |
# |    std                  | 1             |
# |    value_loss           | 1.75          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 10           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 200          |
# | train/                  |              |
# |    approx_kl            | 3.707409e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -14.2        |
# |    explained_variance   | -19.2        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.928        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000902    |
# |    std                  | 1            |
# |    value_loss           | 2.15         |
# ------------------------------------------
# run 7
# Using cpu device
# ---------------------------
# | time/              |    |
# |    fps             | 6  |
# |    iterations      | 1  |
# |    time_elapsed    | 3  |
# |    total_timesteps | 20 |
# ---------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 2             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 40            |
# | train/                  |               |
# |    approx_kl            | 2.3543835e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -24.3         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.438         |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000648     |
# |    std                  | 1             |
# |    value_loss           | 2.35          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 3             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 60            |
# | train/                  |               |
# |    approx_kl            | 4.8518177e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -41.6         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.86          |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000978     |
# |    std                  | 1             |
# |    value_loss           | 3             |
# ...
# | train/                  |             |
# |    approx_kl            | 3.33488e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -14.2       |
# |    explained_variance   | -5.88       |
# |    learning_rate        | 1e-06       |
# |    loss                 | -0.0424     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.000761   |
# |    std                  | 1           |
# |    value_loss           | 0.242       |
# -----------------------------------------
# run 9
# Using cpu device
# ---------------------------
# | time/              |    |
# |    fps             | 6  |
# |    iterations      | 1  |
# |    time_elapsed    | 3  |
# |    total_timesteps | 20 |
# ---------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 40           |
# | train/                  |              |
# |    approx_kl            | 7.122755e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -14.2        |
# |    explained_variance   | -7.45        |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.00127     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000355    |
# |    std                  | 1            |
# |    value_loss           | 0.348        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 3             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 60            |
# | train/                  |               |
# |    approx_kl            | 1.4215708e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -15.6         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.00568       |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000465     |
# |    std                  | 1             |
# |    value_loss           | 0.201         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 4             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 80            |
# | train/                  |               |
# |    approx_kl            | 1.3649463e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -9.98         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0393        |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000479     |
# |    std                  | 1             |
# |    value_loss           | 0.28          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 5             |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 100           |
# | train/                  |               |
# |    approx_kl            | 2.0176171e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -5.91         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0378        |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000507     |
# |    std                  | 1             |
# |    value_loss           | 0.317         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 6             |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 120           |
# | train/                  |               |
# |    approx_kl            | 3.2365322e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -7.39         |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0446       |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.00087      |
# |    std                  | 1             |
# |    value_loss           | 0.352         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 7             |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 140           |
# | train/                  |               |
# |    approx_kl            | 1.6421079e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -8.43         |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0747       |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.00056      |
# |    std                  | 1             |
# |    value_loss           | 0.309         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 8             |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 160           |
# | train/                  |               |
# |    approx_kl            | 1.9222498e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -3.44         |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0584       |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000504     |
# |    std                  | 1             |
# |    value_loss           | 0.231         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 9            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 180          |
# | train/                  |              |
# |    approx_kl            | 3.898144e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -14.2        |
# |    explained_variance   | -8           |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.00486     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00073     |
# |    std                  | 1            |
# |    value_loss           | 0.236        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 10            |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 200           |
# | train/                  |               |
# |    approx_kl            | 3.4660102e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -10.8         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0135        |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000832     |
# |    std                  | 1             |
# |    value_loss           | 0.324         |
# -------------------------------------------
# run 10
# Using cpu device
# ---------------------------
# | time/              |    |
# |    fps             | 6  |
# |    iterations      | 1  |
# |    time_elapsed    | 3  |
# |    total_timesteps | 20 |
# ---------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 2             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 40            |
# | train/                  |               |
# |    approx_kl            | 1.4454126e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -6.86         |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0768       |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000591     |
# |    std                  | 1             |
# |    value_loss           | 0.239         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 3             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 60            |
# | train/                  |               |
# |    approx_kl            | 4.6253203e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -4.45         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0192        |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000795     |
# |    std                  | 1             |
# |    value_loss           | 0.235         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 4             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 80            |
# | train/                  |               |
# |    approx_kl            | 3.3736228e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -4.71         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0179        |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000734     |
# |    std                  | 1             |
# |    value_loss           | 0.265         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 5             |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 100           |
# | train/                  |               |
# |    approx_kl            | 2.6643274e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -7.35         |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0632       |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000651     |
# |    std                  | 1             |
# |    value_loss           | 0.222         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 6             |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 120           |
# | train/                  |               |
# |    approx_kl            | 1.7732382e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -4.51         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.00253       |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000417     |
# |    std                  | 1             |
# |    value_loss           | 0.258         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 7             |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 140           |
# | train/                  |               |
# |    approx_kl            | 2.3633243e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -5.4          |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.048        |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000498     |
# |    std                  | 1             |
# |    value_loss           | 0.19          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 8             |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 160           |
# | train/                  |               |
# |    approx_kl            | 3.4838913e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -3.27         |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0111       |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.00063      |
# |    std                  | 1             |
# |    value_loss           | 0.277         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 9             |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 180           |
# | train/                  |               |
# |    approx_kl            | 1.6599894e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -9.03         |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0359       |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000623     |
# |    std                  | 1             |
# |    value_loss           | 0.292         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 10            |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 200           |
# | train/                  |               |
# |    approx_kl            | 2.1994115e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | -4.7          |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0518       |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000569     |
# |    std                  | 1             |
# |    value_loss           | 0.181         |
# -------------------------------------------

# %%
plt.plot(np.arange(n_total_timesteps),1-np.mean(metrics['history_best_fidelity_runs'],0),'-o', linewidth=1.3)
plt.ylabel('Infidelity')
plt.xlabel('Iteration')
plt.yscale('log')
plt.title('GHZ state infidelity during RL PPO', size=14)
plt.show()
print('Mean best infidelity: ', 1-np.mean(metrics['best_fidelity_runs']))
# Out:
# Mean best infidelity:  0.2750316126475354

# %%
# Test the model
obs = env.reset()
action, _ = model.predict(obs, deterministic=True)
print(f'Best angles: {action}')
print(f'Target function value: {1 - np.abs(target_function(action[0]))}')
# Out:
# Best angles: [[0.0082194  0.         0.0179479  0.         0.00365155 0.01632684
#   0.         0.00117629 0.         0.        ]]
# Target function value: 0.4959834026989526

# %%
data_plot = {   'history_best_fidelity_runs':metrics['history_best_fidelity_runs'],
                'best_thetas_runs': metrics['best_thetas_runs'],
                'best_fidelity_runs':metrics['best_fidelity_runs'],
            } 
if True:
    with open("../results/qoc/results_5ghz_ppo.json", "w") as outfile: 
        json.dump(data_plot, outfile, cls=CustomEncoder)

# %%
import mlflow
#Metrics resume
metrics_reg= {
    'mean_infidelity_runs': 1- np.mean(metrics['best_fidelity_runs']),
    'std_infidelity_runs': np.std(metrics['best_fidelity_runs']),
        }

params['size_final_dataset'] = y_train.shape[0]

mlflow.set_tracking_uri(uri="http://127.0.0.1:8080")
mlflow.set_experiment("QOC_5GHZ")

with mlflow.start_run(run_name='5GHZ_RL_PPO'):

    mlflow.log_params(params)
    mlflow.log_metrics(metrics_reg)
# Out:
# 2024/09/29 07:40:52 INFO mlflow.tracking.fluent: Experiment with name 'QOC_5GHZ' does not exist. Creating a new experiment.
# 2024/09/29 07:40:52 INFO mlflow.tracking._tracking_service.client: 🏃 View run 5GHZ_RL_PPO at: http://127.0.0.1:8080/#/experiments/880741836310625824/runs/73c6f32f4a7c4ff583d971dec5837087.
# 2024/09/29 07:40:52 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:8080/#/experiments/880741836310625824.
