# %% [markdown]
# # Quantum Optimal Control through Reinforcement Learning using TD3 on fidelity
# ### Preparation of the 5 qubit Greenberger–Horne–Zeilinger state (GHZ state)
#
# In this notebook we address the task of creating the GHZ state $\frac{|00000\rangle +|11111\rangle}{\sqrt{2}}$ by optimising on the fidelity

# %%
import numpy as np
from stable_baselines3.common.vec_env import DummyVecEnv
import torch
from matplotlib import pyplot as plt

from qiskit import QuantumCircuit, transpile, assemble
from qiskit_aer import Aer
import numpy as np
import qiskit.quantum_info as qi
from math import pi
import math
from qiskit.quantum_info import Statevector, Operator,  DensityMatrix, state_fidelity
import itertools
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import seaborn as sns
import sys
sys.path.insert(1, '../src/')
from utils.functions import *
from models.models_rl import *

import random

random.seed(10)

# %% [markdown]
# In this cell, we define the quantum circuit designed to prepare the target GHZ state. You can also modify the target state and the initial state directly within this cell, allowing for flexibility in the setup. <br />

# %%
def create_controlled_ghz_circuit(thetas, initial_state):
  

    circ = QuantumCircuit(num_qubits)
    circ.initialize(initial_state)

    for i in range(0,num_qubits):
        circ.ry(thetas[0,i], i)

    for i in range(1,num_qubits):
        circ.cx(0, i)

    for i in range(0,num_qubits):
        circ.rx(thetas[0,i], i)

    return circ


num_qubits = 5
target_state = np.zeros(2**num_qubits)
target_state[0], target_state[-1] = 1, 1
target_state = target_state/np.sqrt(2) 

initial_state = np.zeros(2**num_qubits)
initial_state[0] = 1
n_thetas = 10 #Number of parameters


ghz_visualization = create_controlled_ghz_circuit(np.zeros(n_thetas)[np.newaxis,:],initial_state)

ghz_visualization.draw('mpl')

# %% [markdown]
# We define the function to optimise

# %%
ghz_contr_circuit = create_controlled_ghz_circuit
def target_function(new_sample):
    _, new_fid_real, _ = get_expectation_values(ghz_contr_circuit, new_sample[np.newaxis,:],initial_state, target_state) #Get the real values

    return -new_fid_real

# %%
# Train the model
n_total_timesteps = 200
n_run = 5

params = {'lr': 0.0000001,
          'batch_size':5,
          'gamma':0.99,  
          'n_run':n_run,
          'n_total_timesteps': n_total_timesteps,
          'noise_std':0.01  ,
           'n_epochs': 20,
          }

metrics = {
    'best_fidelity_runs': np.zeros(n_run),
    'history_best_fidelity_runs': np.zeros((n_run, n_total_timesteps)),
    'value_losses_runs':np.zeros((n_run,n_total_timesteps)),
    'best_thetas_runs': np.zeros((n_run,n_thetas))
    }


for iter_run in range(n_run):
    print('run',iter_run+1)
    # Create the environment
    env = DummyVecEnv([lambda: OptimizationEnv(target_function=target_function, num_thetas=n_thetas)])
    metrics_callback = MetricsCallback()

   # Define the noise for exploration used in TD3
    n_actions = env.action_space.shape[-1]
    action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=params['noise_std']* np.ones(n_actions))

    # Create the model
    model = TD3(
        CustomTD3Policy, 
        env,
        action_noise=action_noise,
        verbose=1,
        learning_rate=params['lr'],  
        batch_size=params['batch_size'],  # Minibatch size for each gradient update
        gamma=params['gamma'],  # Discount factor
    )


    model.learn(total_timesteps=n_total_timesteps, callback=metrics_callback )

    X_train = np.array(env.envs[0].states) #Thetas
    y_train = np.abs(env.envs[0].rewards) #Fidelity
    best_thetas = env.envs[0].best_thetas
    best_fidelity = env.envs[0].best_value

    metrics['best_fidelity_runs'][iter_run] = np.abs((env.envs[0]).history[-1]) 
    metrics['history_best_fidelity_runs'][iter_run,:] = np.abs(env.envs[0].history)
    metrics['value_losses_runs'][iter_run] = metrics_callback.value_losses
    metrics['best_thetas_runs'][iter_run,:] = best_thetas
# Out:
# run 1
# Using cpu device
# --------------------------
# | time/              |   |
# |    episodes        | 4 |
# |    fps             | 7 |
# |    time_elapsed    | 0 |
# |    total_timesteps | 4 |
# --------------------------
# --------------------------
# | time/              |   |
# |    episodes        | 8 |
# |    fps             | 7 |
# |    time_elapsed    | 1 |
# |    total_timesteps | 8 |
# --------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 12 |
# |    fps             | 7  |
# |    time_elapsed    | 1  |
# |    total_timesteps | 12 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 16 |
# |    fps             | 7  |
# |    time_elapsed    | 2  |
# |    total_timesteps | 16 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 20 |
# |    fps             | 7  |
# |    time_elapsed    | 2  |
# |    total_timesteps | 20 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 24 |
# |    fps             | 7  |
# |    time_elapsed    | 3  |
# |    total_timesteps | 24 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 28 |
# |    fps             | 7  |
# |    time_elapsed    | 3  |
# |    total_timesteps | 28 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 32 |
# |    fps             | 7  |
# |    time_elapsed    | 4  |
# |    total_timesteps | 32 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 36 |
# |    fps             | 7  |
# |    time_elapsed    | 4  |
# |    total_timesteps | 36 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 40 |
# |    fps             | 7  |
# |    time_elapsed    | 5  |
# |    total_timesteps | 40 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 44 |
# |    fps             | 7  |
# |    time_elapsed    | 5  |
# |    total_timesteps | 44 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 48 |
# |    fps             | 7  |
# |    time_elapsed    | 6  |
# |    total_timesteps | 48 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 52 |
# |    fps             | 7  |
# |    time_elapsed    | 6  |
# |    total_timesteps | 52 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 56 |
# |    fps             | 7  |
# |    time_elapsed    | 7  |
# |    total_timesteps | 56 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 60 |
# |    fps             | 7  |
# |    time_elapsed    | 8  |
# |    total_timesteps | 60 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 64 |
# |    fps             | 7  |
# |    time_elapsed    | 8  |
# |    total_timesteps | 64 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 68 |
# |    fps             | 7  |
# |    time_elapsed    | 9  |
# |    total_timesteps | 68 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 72 |
# |    fps             | 7  |
# |    time_elapsed    | 10 |
# |    total_timesteps | 72 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 76 |
# |    fps             | 6  |
# |    time_elapsed    | 10 |
# |    total_timesteps | 76 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 80 |
# |    fps             | 6  |
# |    time_elapsed    | 11 |
# |    total_timesteps | 80 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 84 |
# |    fps             | 6  |
# |    time_elapsed    | 12 |
# |    total_timesteps | 84 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 88 |
# |    fps             | 6  |
# |    time_elapsed    | 12 |
# |    total_timesteps | 88 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 92 |
# |    fps             | 6  |
# |    time_elapsed    | 13 |
# |    total_timesteps | 92 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 96 |
# |    fps             | 6  |
# |    time_elapsed    | 14 |
# |    total_timesteps | 96 |
# ---------------------------
# ----------------------------
# | time/              |     |
# |    episodes        | 100 |
# |    fps             | 6   |
# |    time_elapsed    | 14  |
# |    total_timesteps | 100 |
# ----------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 6        |
# |    time_elapsed    | 15       |
# |    total_timesteps | 104      |
# | train/             |          |
# |    actor_loss      | 0.0252   |
# |    critic_loss     | 0.0436   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 3        |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 6        |
# |    time_elapsed    | 16       |
# |    total_timesteps | 108      |
# | train/             |          |
# |    actor_loss      | 0.0203   |
# |    critic_loss     | 0.0498   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 7        |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 6        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 112      |
# | train/             |          |
# |    actor_loss      | 0.0142   |
# |    critic_loss     | 0.0713   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 11       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 6        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 116      |
# | train/             |          |
# |    actor_loss      | 0.0172   |
# |    critic_loss     | 0.0749   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 15       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 6        |
# |    time_elapsed    | 18       |
# |    total_timesteps | 120      |
# | train/             |          |
# |    actor_loss      | 0.0148   |
# |    critic_loss     | 0.0567   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 19       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 6        |
# |    time_elapsed    | 19       |
# |    total_timesteps | 124      |
# | train/             |          |
# |    actor_loss      | 0.00597  |
# |    critic_loss     | 0.00278  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 23       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 6        |
# |    time_elapsed    | 19       |
# |    total_timesteps | 128      |
# | train/             |          |
# |    actor_loss      | 0.0226   |
# |    critic_loss     | 0.0348   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 27       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 6        |
# |    time_elapsed    | 20       |
# |    total_timesteps | 132      |
# | train/             |          |
# |    actor_loss      | 0.0177   |
# |    critic_loss     | 0.00727  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 31       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 6        |
# |    time_elapsed    | 20       |
# |    total_timesteps | 136      |
# | train/             |          |
# |    actor_loss      | 0.0102   |
# |    critic_loss     | 0.0232   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 35       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 6        |
# |    time_elapsed    | 21       |
# |    total_timesteps | 140      |
# | train/             |          |
# |    actor_loss      | 0.00114  |
# |    critic_loss     | 0.0583   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 39       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 6        |
# |    time_elapsed    | 22       |
# |    total_timesteps | 144      |
# | train/             |          |
# |    actor_loss      | 0.00487  |
# |    critic_loss     | 0.00107  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 43       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 6        |
# |    time_elapsed    | 23       |
# |    total_timesteps | 148      |
# | train/             |          |
# |    actor_loss      | 0.00989  |
# |    critic_loss     | 0.0787   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 47       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 6        |
# |    time_elapsed    | 23       |
# |    total_timesteps | 152      |
# | train/             |          |
# |    actor_loss      | 0.0176   |
# |    critic_loss     | 0.0258   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 51       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 6        |
# |    time_elapsed    | 24       |
# |    total_timesteps | 156      |
# | train/             |          |
# |    actor_loss      | 0.0234   |
# |    critic_loss     | 0.0392   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 55       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 6        |
# |    time_elapsed    | 25       |
# |    total_timesteps | 160      |
# | train/             |          |
# |    actor_loss      | 0.0139   |
# |    critic_loss     | 0.000924 |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 59       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 6        |
# |    time_elapsed    | 26       |
# |    total_timesteps | 164      |
# | train/             |          |
# |    actor_loss      | 0.0197   |
# |    critic_loss     | 0.000569 |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 63       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 6        |
# |    time_elapsed    | 26       |
# |    total_timesteps | 168      |
# | train/             |          |
# |    actor_loss      | 0.0227   |
# |    critic_loss     | 0.000683 |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 67       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 6        |
# |    time_elapsed    | 27       |
# |    total_timesteps | 172      |
# | train/             |          |
# |    actor_loss      | 0.0202   |
# |    critic_loss     | 0.00142  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 71       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 6        |
# |    time_elapsed    | 28       |
# |    total_timesteps | 176      |
# | train/             |          |
# |    actor_loss      | 0.0228   |
# |    critic_loss     | 0.0231   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 75       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 6        |
# |    time_elapsed    | 28       |
# |    total_timesteps | 180      |
# | train/             |          |
# |    actor_loss      | 0.0132   |
# |    critic_loss     | 0.000915 |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 79       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 6        |
# |    time_elapsed    | 29       |
# |    total_timesteps | 184      |
# | train/             |          |
# |    actor_loss      | 0.016    |
# |    critic_loss     | 0.000821 |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 83       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 6        |
# |    time_elapsed    | 30       |
# |    total_timesteps | 188      |
# | train/             |          |
# |    actor_loss      | 0.015    |
# |    critic_loss     | 0.0878   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 87       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 6        |
# |    time_elapsed    | 30       |
# |    total_timesteps | 192      |
# | train/             |          |
# |    actor_loss      | 0.0214   |
# |    critic_loss     | 0.000967 |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 91       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 6        |
# |    time_elapsed    | 31       |
# |    total_timesteps | 196      |
# | train/             |          |
# |    actor_loss      | 0.0146   |
# |    critic_loss     | 0.000712 |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 95       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 6        |
# |    time_elapsed    | 31       |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | 0.0146   |
# |    critic_loss     | 0.0473   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 99       |
# ---------------------------------
# run 2
# Using cpu device
# --------------------------
# | time/              |   |
# |    episodes        | 4 |
# |    fps             | 6 |
# |    time_elapsed    | 0 |
# |    total_timesteps | 4 |
# --------------------------
# --------------------------
# | time/              |   |
# |    episodes        | 8 |
# |    fps             | 6 |
# |    time_elapsed    | 1 |
# |    total_timesteps | 8 |
# --------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 12 |
# |    fps             | 6  |
# |    time_elapsed    | 1  |
# |    total_timesteps | 12 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 16 |
# |    fps             | 6  |
# |    time_elapsed    | 2  |
# |    total_timesteps | 16 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 20 |
# |    fps             | 6  |
# |    time_elapsed    | 3  |
# |    total_timesteps | 20 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 24 |
# |    fps             | 6  |
# |    time_elapsed    | 3  |
# |    total_timesteps | 24 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 28 |
# |    fps             | 6  |
# |    time_elapsed    | 4  |
# |    total_timesteps | 28 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 32 |
# |    fps             | 6  |
# |    time_elapsed    | 5  |
# |    total_timesteps | 32 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 36 |
# |    fps             | 6  |
# |    time_elapsed    | 5  |
# |    total_timesteps | 36 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 40 |
# |    fps             | 6  |
# |    time_elapsed    | 6  |
# |    total_timesteps | 40 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 44 |
# |    fps             | 5  |
# |    time_elapsed    | 7  |
# |    total_timesteps | 44 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 48 |
# |    fps             | 5  |
# |    time_elapsed    | 8  |
# |    total_timesteps | 48 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 52 |
# |    fps             | 5  |
# |    time_elapsed    | 8  |
# |    total_timesteps | 52 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 56 |
# |    fps             | 5  |
# |    time_elapsed    | 9  |
# |    total_timesteps | 56 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 60 |
# |    fps             | 5  |
# |    time_elapsed    | 10 |
# |    total_timesteps | 60 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 64 |
# |    fps             | 5  |
# |    time_elapsed    | 10 |
# |    total_timesteps | 64 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 68 |
# |    fps             | 5  |
# |    time_elapsed    | 11 |
# |    total_timesteps | 68 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 72 |
# |    fps             | 5  |
# |    time_elapsed    | 12 |
# |    total_timesteps | 72 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 76 |
# |    fps             | 5  |
# |    time_elapsed    | 13 |
# |    total_timesteps | 76 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 80 |
# |    fps             | 5  |
# |    time_elapsed    | 13 |
# |    total_timesteps | 80 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 84 |
# |    fps             | 5  |
# |    time_elapsed    | 14 |
# |    total_timesteps | 84 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 88 |
# |    fps             | 5  |
# |    time_elapsed    | 15 |
# |    total_timesteps | 88 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 92 |
# |    fps             | 5  |
# |    time_elapsed    | 15 |
# |    total_timesteps | 92 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 96 |
# |    fps             | 5  |
# |    time_elapsed    | 16 |
# |    total_timesteps | 96 |
# ---------------------------
# ----------------------------
# | time/              |     |
# |    episodes        | 100 |
# |    fps             | 5   |
# |    time_elapsed    | 16  |
# |    total_timesteps | 100 |
# ----------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 5        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 104      |
# | train/             |          |
# |    actor_loss      | 0.00508  |
# |    critic_loss     | 0.0171   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 3        |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 5        |
# |    time_elapsed    | 18       |
# |    total_timesteps | 108      |
# | train/             |          |
# |    actor_loss      | -0.0106  |
# |    critic_loss     | 0.00196  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 7        |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 5        |
# |    time_elapsed    | 18       |
# |    total_timesteps | 112      |
# | train/             |          |
# |    actor_loss      | 0.00565  |
# |    critic_loss     | 0.00582  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 11       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 5        |
# |    time_elapsed    | 19       |
# |    total_timesteps | 116      |
# | train/             |          |
# |    actor_loss      | 0.00645  |
# |    critic_loss     | 0.00561  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 15       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 5        |
# |    time_elapsed    | 20       |
# |    total_timesteps | 120      |
# | train/             |          |
# |    actor_loss      | 0.00332  |
# |    critic_loss     | 0.00939  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 19       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 6        |
# |    time_elapsed    | 20       |
# |    total_timesteps | 124      |
# | train/             |          |
# |    actor_loss      | 0.0246   |
# |    critic_loss     | 0.00181  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 23       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 6        |
# |    time_elapsed    | 21       |
# |    total_timesteps | 128      |
# | train/             |          |
# |    actor_loss      | 0.0169   |
# |    critic_loss     | 0.00958  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 27       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 6        |
# |    time_elapsed    | 21       |
# |    total_timesteps | 132      |
# | train/             |          |
# |    actor_loss      | 0.00936  |
# |    critic_loss     | 0.0234   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 31       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 6        |
# |    time_elapsed    | 22       |
# |    total_timesteps | 136      |
# | train/             |          |
# |    actor_loss      | 0.00748  |
# |    critic_loss     | 0.00812  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 35       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 6        |
# |    time_elapsed    | 23       |
# |    total_timesteps | 140      |
# | train/             |          |
# |    actor_loss      | 0.0291   |
# |    critic_loss     | 0.0372   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 39       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 5        |
# |    time_elapsed    | 24       |
# |    total_timesteps | 144      |
# | train/             |          |
# |    actor_loss      | 0.0156   |
# |    critic_loss     | 0.0121   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 43       |
# ---------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 148       |
# |    fps             | 5         |
# |    time_elapsed    | 24        |
# |    total_timesteps | 148       |
# | train/             |           |
# |    actor_loss      | -0.000618 |
# |    critic_loss     | 0.00257   |
# |    learning_rate   | 1e-07     |
# |    n_updates       | 47        |
# ----------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 6        |
# |    time_elapsed    | 25       |
# |    total_timesteps | 152      |
# | train/             |          |
# |    actor_loss      | -0.00257 |
# |    critic_loss     | 0.00371  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 51       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 6        |
# |    time_elapsed    | 25       |
# |    total_timesteps | 156      |
# | train/             |          |
# |    actor_loss      | 0.0166   |
# |    critic_loss     | 0.0728   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 55       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 6        |
# |    time_elapsed    | 26       |
# |    total_timesteps | 160      |
# | train/             |          |
# |    actor_loss      | -0.00619 |
# |    critic_loss     | 0.0297   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 59       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 6        |
# |    time_elapsed    | 27       |
# |    total_timesteps | 164      |
# | train/             |          |
# |    actor_loss      | 0.013    |
# |    critic_loss     | 0.000405 |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 63       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 6        |
# |    time_elapsed    | 27       |
# |    total_timesteps | 168      |
# | train/             |          |
# |    actor_loss      | 0.0135   |
# |    critic_loss     | 0.0116   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 67       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 6        |
# |    time_elapsed    | 28       |
# |    total_timesteps | 172      |
# | train/             |          |
# |    actor_loss      | 0.0135   |
# |    critic_loss     | 0.00803  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 71       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 6        |
# |    time_elapsed    | 29       |
# |    total_timesteps | 176      |
# | train/             |          |
# |    actor_loss      | -0.0101  |
# |    critic_loss     | 0.0126   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 75       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 6        |
# |    time_elapsed    | 29       |
# |    total_timesteps | 180      |
# | train/             |          |
# |    actor_loss      | 0.00163  |
# |    critic_loss     | 0.0116   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 79       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 6        |
# |    time_elapsed    | 30       |
# |    total_timesteps | 184      |
# | train/             |          |
# |    actor_loss      | -0.00717 |
# |    critic_loss     | 0.00473  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 83       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 6        |
# |    time_elapsed    | 31       |
# |    total_timesteps | 188      |
# | train/             |          |
# |    actor_loss      | 0.00965  |
# |    critic_loss     | 0.00182  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 87       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 6        |
# |    time_elapsed    | 31       |
# |    total_timesteps | 192      |
# | train/             |          |
# |    actor_loss      | 0.0143   |
# |    critic_loss     | 0.00106  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 91       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 6        |
# |    time_elapsed    | 32       |
# |    total_timesteps | 196      |
# | train/             |          |
# |    actor_loss      | 0.00126  |
# |    critic_loss     | 0.01     |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 95       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 6        |
# |    time_elapsed    | 33       |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | 0.00489  |
# |    critic_loss     | 0.0069   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 99       |
# ---------------------------------
# run 3
# Using cpu device
# --------------------------
# | time/              |   |
# |    episodes        | 4 |
# |    fps             | 6 |
# |    time_elapsed    | 0 |
# |    total_timesteps | 4 |
# --------------------------
# --------------------------
# | time/              |   |
# |    episodes        | 8 |
# |    fps             | 6 |
# |    time_elapsed    | 1 |
# |    total_timesteps | 8 |
# --------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 12 |
# |    fps             | 6  |
# |    time_elapsed    | 1  |
# |    total_timesteps | 12 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 16 |
# |    fps             | 6  |
# |    time_elapsed    | 2  |
# |    total_timesteps | 16 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 20 |
# |    fps             | 6  |
# |    time_elapsed    | 3  |
# |    total_timesteps | 20 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 24 |
# |    fps             | 6  |
# |    time_elapsed    | 3  |
# |    total_timesteps | 24 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 28 |
# |    fps             | 6  |
# |    time_elapsed    | 4  |
# |    total_timesteps | 28 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 32 |
# |    fps             | 6  |
# |    time_elapsed    | 4  |
# |    total_timesteps | 32 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 36 |
# |    fps             | 6  |
# |    time_elapsed    | 5  |
# |    total_timesteps | 36 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 40 |
# |    fps             | 6  |
# |    time_elapsed    | 6  |
# |    total_timesteps | 40 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 44 |
# |    fps             | 6  |
# |    time_elapsed    | 6  |
# |    total_timesteps | 44 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 48 |
# |    fps             | 6  |
# |    time_elapsed    | 7  |
# |    total_timesteps | 48 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 52 |
# |    fps             | 6  |
# |    time_elapsed    | 8  |
# |    total_timesteps | 52 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 56 |
# |    fps             | 6  |
# |    time_elapsed    | 9  |
# |    total_timesteps | 56 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 60 |
# |    fps             | 6  |
# |    time_elapsed    | 9  |
# |    total_timesteps | 60 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 64 |
# |    fps             | 6  |
# |    time_elapsed    | 10 |
# |    total_timesteps | 64 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 68 |
# |    fps             | 6  |
# |    time_elapsed    | 10 |
# |    total_timesteps | 68 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 72 |
# |    fps             | 6  |
# |    time_elapsed    | 11 |
# |    total_timesteps | 72 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 76 |
# |    fps             | 6  |
# |    time_elapsed    | 12 |
# |    total_timesteps | 76 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 80 |
# |    fps             | 6  |
# |    time_elapsed    | 12 |
# |    total_timesteps | 80 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 84 |
# |    fps             | 6  |
# |    time_elapsed    | 13 |
# |    total_timesteps | 84 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 88 |
# |    fps             | 6  |
# |    time_elapsed    | 14 |
# |    total_timesteps | 88 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 92 |
# |    fps             | 6  |
# |    time_elapsed    | 14 |
# |    total_timesteps | 92 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 96 |
# |    fps             | 6  |
# |    time_elapsed    | 15 |
# |    total_timesteps | 96 |
# ---------------------------
# ----------------------------
# | time/              |     |
# |    episodes        | 100 |
# |    fps             | 6   |
# |    time_elapsed    | 16  |
# |    total_timesteps | 100 |
# ----------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 6        |
# |    time_elapsed    | 16       |
# |    total_timesteps | 104      |
# | train/             |          |
# |    actor_loss      | 0.0469   |
# |    critic_loss     | 0.00809  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 3        |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 6        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 108      |
# | train/             |          |
# |    actor_loss      | 0.0447   |
# |    critic_loss     | 0.0616   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 7        |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 6        |
# |    time_elapsed    | 18       |
# |    total_timesteps | 112      |
# | train/             |          |
# |    actor_loss      | 0.0444   |
# |    critic_loss     | 0.0889   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 11       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 6        |
# |    time_elapsed    | 18       |
# |    total_timesteps | 116      |
# | train/             |          |
# |    actor_loss      | 0.0535   |
# |    critic_loss     | 0.0145   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 15       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 6        |
# |    time_elapsed    | 19       |
# |    total_timesteps | 120      |
# | train/             |          |
# |    actor_loss      | 0.039    |
# |    critic_loss     | 0.024    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 19       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 6        |
# |    time_elapsed    | 20       |
# |    total_timesteps | 124      |
# | train/             |          |
# |    actor_loss      | 0.0375   |
# |    critic_loss     | 0.0131   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 23       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 6        |
# |    time_elapsed    | 20       |
# |    total_timesteps | 128      |
# | train/             |          |
# |    actor_loss      | 0.0455   |
# |    critic_loss     | 0.00943  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 27       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 6        |
# |    time_elapsed    | 21       |
# |    total_timesteps | 132      |
# | train/             |          |
# |    actor_loss      | 0.0415   |
# |    critic_loss     | 0.00328  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 31       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 6        |
# |    time_elapsed    | 22       |
# |    total_timesteps | 136      |
# | train/             |          |
# |    actor_loss      | 0.0429   |
# |    critic_loss     | 0.0152   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 35       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 6        |
# |    time_elapsed    | 22       |
# |    total_timesteps | 140      |
# | train/             |          |
# |    actor_loss      | 0.0424   |
# |    critic_loss     | 0.00795  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 39       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 6        |
# |    time_elapsed    | 23       |
# |    total_timesteps | 144      |
# | train/             |          |
# |    actor_loss      | 0.0359   |
# |    critic_loss     | 0.0179   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 43       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 6        |
# |    time_elapsed    | 24       |
# |    total_timesteps | 148      |
# | train/             |          |
# |    actor_loss      | 0.0627   |
# |    critic_loss     | 0.0421   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 47       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 6        |
# |    time_elapsed    | 24       |
# |    total_timesteps | 152      |
# | train/             |          |
# |    actor_loss      | 0.0452   |
# |    critic_loss     | 0.0123   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 51       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 6        |
# |    time_elapsed    | 25       |
# |    total_timesteps | 156      |
# | train/             |          |
# |    actor_loss      | 0.0312   |
# |    critic_loss     | 0.0212   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 55       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 6        |
# |    time_elapsed    | 26       |
# |    total_timesteps | 160      |
# | train/             |          |
# |    actor_loss      | 0.0378   |
# |    critic_loss     | 0.032    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 59       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 6        |
# |    time_elapsed    | 27       |
# |    total_timesteps | 164      |
# | train/             |          |
# |    actor_loss      | 0.0319   |
# |    critic_loss     | 0.0245   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 63       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 6        |
# |    time_elapsed    | 27       |
# |    total_timesteps | 168      |
# | train/             |          |
# |    actor_loss      | 0.0567   |
# |    critic_loss     | 0.0042   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 67       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 6        |
# |    time_elapsed    | 28       |
# |    total_timesteps | 172      |
# | train/             |          |
# |    actor_loss      | 0.0447   |
# |    critic_loss     | 0.0318   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 71       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 6        |
# |    time_elapsed    | 28       |
# |    total_timesteps | 176      |
# | train/             |          |
# |    actor_loss      | 0.0448   |
# |    critic_loss     | 0.00619  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 75       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 6        |
# |    time_elapsed    | 29       |
# |    total_timesteps | 180      |
# | train/             |          |
# |    actor_loss      | 0.0501   |
# |    critic_loss     | 0.0215   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 79       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 6        |
# |    time_elapsed    | 30       |
# |    total_timesteps | 184      |
# | train/             |          |
# |    actor_loss      | 0.0582   |
# |    critic_loss     | 0.00773  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 83       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 6        |
# |    time_elapsed    | 31       |
# |    total_timesteps | 188      |
# | train/             |          |
# |    actor_loss      | 0.0502   |
# |    critic_loss     | 0.00844  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 87       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 6        |
# |    time_elapsed    | 31       |
# |    total_timesteps | 192      |
# | train/             |          |
# |    actor_loss      | 0.0379   |
# |    critic_loss     | 0.00561  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 91       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 6        |
# |    time_elapsed    | 32       |
# |    total_timesteps | 196      |
# | train/             |          |
# |    actor_loss      | 0.0378   |
# |    critic_loss     | 0.00898  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 95       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 6        |
# |    time_elapsed    | 32       |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | 0.0529   |
# |    critic_loss     | 0.00345  |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 99       |
# ---------------------------------
# run 4
# Using cpu device
# --------------------------
# | time/              |   |
# |    episodes        | 4 |
# |    fps             | 5 |
# |    time_elapsed    | 0 |
# |    total_timesteps | 4 |
# --------------------------
# --------------------------
# | time/              |   |
# |    episodes        | 8 |
# |    fps             | 6 |
# |    time_elapsed    | 1 |
# |    total_timesteps | 8 |
# --------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 12 |
# |    fps             | 6  |
# |    time_elapsed    | 1  |
# |    total_timesteps | 12 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 16 |
# |    fps             | 6  |
# |    time_elapsed    | 2  |
# |    total_timesteps | 16 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 20 |
# |    fps             | 6  |
# |    time_elapsed    | 3  |
# |    total_timesteps | 20 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 24 |
# |    fps             | 6  |
# |    time_elapsed    | 3  |
# |    total_timesteps | 24 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 28 |
# |    fps             | 6  |
# |    time_elapsed    | 4  |
# |    total_timesteps | 28 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 32 |
# |    fps             | 6  |
# |    time_elapsed    | 4  |
# |    total_timesteps | 32 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 36 |
# |    fps             | 6  |
# |    time_elapsed    | 5  |
# |    total_timesteps | 36 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 40 |
# |    fps             | 6  |
# |    time_elapsed    | 6  |
# |    total_timesteps | 40 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 44 |
# |    fps             | 6  |
# |    time_elapsed    | 6  |
# |    total_timesteps | 44 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 48 |
# |    fps             | 6  |
# |    time_elapsed    | 7  |
# |    total_timesteps | 48 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 52 |
# |    fps             | 6  |
# |    time_elapsed    | 8  |
# |    total_timesteps | 52 |
# ---------------------------
# ---------------------------
# | time/              |    |
# ...
# |    n_updates       | 91       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 6        |
# |    time_elapsed    | 32       |
# |    total_timesteps | 196      |
# | train/             |          |
# |    actor_loss      | 0.0709   |
# |    critic_loss     | 0.0939   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 95       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 6        |
# |    time_elapsed    | 33       |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | 0.0701   |
# |    critic_loss     | 0.0346   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 99       |
# ---------------------------------
# run 5
# Using cpu device
# --------------------------
# | time/              |   |
# |    episodes        | 4 |
# |    fps             | 5 |
# |    time_elapsed    | 0 |
# |    total_timesteps | 4 |
# --------------------------
# --------------------------
# | time/              |   |
# |    episodes        | 8 |
# |    fps             | 5 |
# |    time_elapsed    | 1 |
# |    total_timesteps | 8 |
# --------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 12 |
# |    fps             | 5  |
# |    time_elapsed    | 2  |
# |    total_timesteps | 12 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 16 |
# |    fps             | 5  |
# |    time_elapsed    | 2  |
# |    total_timesteps | 16 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 20 |
# |    fps             | 5  |
# |    time_elapsed    | 3  |
# |    total_timesteps | 20 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 24 |
# |    fps             | 5  |
# |    time_elapsed    | 4  |
# |    total_timesteps | 24 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 28 |
# |    fps             | 6  |
# |    time_elapsed    | 4  |
# |    total_timesteps | 28 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 32 |
# |    fps             | 6  |
# |    time_elapsed    | 5  |
# |    total_timesteps | 32 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 36 |
# |    fps             | 6  |
# |    time_elapsed    | 5  |
# |    total_timesteps | 36 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 40 |
# |    fps             | 6  |
# |    time_elapsed    | 6  |
# |    total_timesteps | 40 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 44 |
# |    fps             | 6  |
# |    time_elapsed    | 7  |
# |    total_timesteps | 44 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 48 |
# |    fps             | 6  |
# |    time_elapsed    | 7  |
# |    total_timesteps | 48 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 52 |
# |    fps             | 6  |
# |    time_elapsed    | 8  |
# |    total_timesteps | 52 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 56 |
# |    fps             | 6  |
# |    time_elapsed    | 9  |
# |    total_timesteps | 56 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 60 |
# |    fps             | 6  |
# |    time_elapsed    | 9  |
# |    total_timesteps | 60 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 64 |
# |    fps             | 6  |
# |    time_elapsed    | 10 |
# |    total_timesteps | 64 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 68 |
# |    fps             | 6  |
# |    time_elapsed    | 10 |
# |    total_timesteps | 68 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 72 |
# |    fps             | 6  |
# |    time_elapsed    | 11 |
# |    total_timesteps | 72 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 76 |
# |    fps             | 6  |
# |    time_elapsed    | 12 |
# |    total_timesteps | 76 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 80 |
# |    fps             | 6  |
# |    time_elapsed    | 12 |
# |    total_timesteps | 80 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 84 |
# |    fps             | 6  |
# |    time_elapsed    | 13 |
# |    total_timesteps | 84 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 88 |
# |    fps             | 6  |
# |    time_elapsed    | 13 |
# |    total_timesteps | 88 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 92 |
# |    fps             | 6  |
# |    time_elapsed    | 14 |
# |    total_timesteps | 92 |
# ---------------------------
# ---------------------------
# | time/              |    |
# |    episodes        | 96 |
# |    fps             | 6  |
# |    time_elapsed    | 15 |
# |    total_timesteps | 96 |
# ---------------------------
# ----------------------------
# | time/              |     |
# |    episodes        | 100 |
# |    fps             | 6   |
# |    time_elapsed    | 15  |
# |    total_timesteps | 100 |
# ----------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 6        |
# |    time_elapsed    | 16       |
# |    total_timesteps | 104      |
# | train/             |          |
# |    actor_loss      | 0.132    |
# |    critic_loss     | 0.0189   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 3        |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 6        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 108      |
# | train/             |          |
# |    actor_loss      | 0.13     |
# |    critic_loss     | 0.0211   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 7        |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 6        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 112      |
# | train/             |          |
# |    actor_loss      | 0.141    |
# |    critic_loss     | 0.0187   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 11       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 6        |
# |    time_elapsed    | 18       |
# |    total_timesteps | 116      |
# | train/             |          |
# |    actor_loss      | 0.139    |
# |    critic_loss     | 0.0241   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 15       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 6        |
# |    time_elapsed    | 19       |
# |    total_timesteps | 120      |
# | train/             |          |
# |    actor_loss      | 0.126    |
# |    critic_loss     | 0.0172   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 19       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 6        |
# |    time_elapsed    | 19       |
# |    total_timesteps | 124      |
# | train/             |          |
# |    actor_loss      | 0.134    |
# |    critic_loss     | 0.0282   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 23       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 6        |
# |    time_elapsed    | 20       |
# |    total_timesteps | 128      |
# | train/             |          |
# |    actor_loss      | 0.12     |
# |    critic_loss     | 0.0308   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 27       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 6        |
# |    time_elapsed    | 21       |
# |    total_timesteps | 132      |
# | train/             |          |
# |    actor_loss      | 0.145    |
# |    critic_loss     | 0.0417   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 31       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 6        |
# |    time_elapsed    | 21       |
# |    total_timesteps | 136      |
# | train/             |          |
# |    actor_loss      | 0.139    |
# |    critic_loss     | 0.0145   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 35       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 6        |
# |    time_elapsed    | 22       |
# |    total_timesteps | 140      |
# | train/             |          |
# |    actor_loss      | 0.11     |
# |    critic_loss     | 0.0252   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 39       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 6        |
# |    time_elapsed    | 23       |
# |    total_timesteps | 144      |
# | train/             |          |
# |    actor_loss      | 0.128    |
# |    critic_loss     | 0.0242   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 43       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 6        |
# |    time_elapsed    | 23       |
# |    total_timesteps | 148      |
# | train/             |          |
# |    actor_loss      | 0.133    |
# |    critic_loss     | 0.0236   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 47       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 6        |
# |    time_elapsed    | 24       |
# |    total_timesteps | 152      |
# | train/             |          |
# |    actor_loss      | 0.12     |
# |    critic_loss     | 0.0526   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 51       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 6        |
# |    time_elapsed    | 25       |
# |    total_timesteps | 156      |
# | train/             |          |
# |    actor_loss      | 0.121    |
# |    critic_loss     | 0.0185   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 55       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 6        |
# |    time_elapsed    | 25       |
# |    total_timesteps | 160      |
# | train/             |          |
# |    actor_loss      | 0.139    |
# |    critic_loss     | 0.0169   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 59       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 6        |
# |    time_elapsed    | 26       |
# |    total_timesteps | 164      |
# | train/             |          |
# |    actor_loss      | 0.13     |
# |    critic_loss     | 0.0449   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 63       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 6        |
# |    time_elapsed    | 27       |
# |    total_timesteps | 168      |
# | train/             |          |
# |    actor_loss      | 0.135    |
# |    critic_loss     | 0.0206   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 67       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 6        |
# |    time_elapsed    | 27       |
# |    total_timesteps | 172      |
# | train/             |          |
# |    actor_loss      | 0.125    |
# |    critic_loss     | 0.0264   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 71       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 6        |
# |    time_elapsed    | 28       |
# |    total_timesteps | 176      |
# | train/             |          |
# |    actor_loss      | 0.129    |
# |    critic_loss     | 0.0436   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 75       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 6        |
# |    time_elapsed    | 29       |
# |    total_timesteps | 180      |
# | train/             |          |
# |    actor_loss      | 0.134    |
# |    critic_loss     | 0.0154   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 79       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 6        |
# |    time_elapsed    | 29       |
# |    total_timesteps | 184      |
# | train/             |          |
# |    actor_loss      | 0.12     |
# |    critic_loss     | 0.0226   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 83       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 6        |
# |    time_elapsed    | 30       |
# |    total_timesteps | 188      |
# | train/             |          |
# |    actor_loss      | 0.151    |
# |    critic_loss     | 0.0256   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 87       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 6        |
# |    time_elapsed    | 31       |
# |    total_timesteps | 192      |
# | train/             |          |
# |    actor_loss      | 0.135    |
# |    critic_loss     | 0.0263   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 91       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 6        |
# |    time_elapsed    | 31       |
# |    total_timesteps | 196      |
# | train/             |          |
# |    actor_loss      | 0.147    |
# |    critic_loss     | 0.0444   |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 95       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 6        |
# |    time_elapsed    | 32       |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | 0.139    |
# |    critic_loss     | 0.051    |
# |    learning_rate   | 1e-07    |
# |    n_updates       | 99       |
# ---------------------------------

# %%
plt.plot(np.arange(n_total_timesteps),1-np.mean(metrics['history_best_fidelity_runs'],0),'-o', linewidth=1.3)
plt.ylabel('Infidelity')
plt.xlabel('Iteration')
plt.yscale('log')
plt.title('GHZ state infidelity during RL TD3', size=14)
plt.show()
print('Mean best infidelity: ', 1-np.mean(metrics['best_fidelity_runs']))
# Out:
# Mean best infidelity:  0.5486799330068962

# %%
# Test the model
obs = env.reset()
action, _ = model.predict(obs, deterministic=True)
print(f'Best angles: {action}')
print(f'Target function value: {1 - np.abs(target_function(action[0]))}')
# Out:
# Best angles: [[2.869803  3.2006843 3.0119174 3.0748935 2.6745765 2.8354435 3.1181169
#   3.0763116 2.930323  3.2353475]]
# Target function value: 0.9896682869560274

# %%
data_plot = {   'history_best_fidelity_runs':metrics['history_best_fidelity_runs'],
                'best_thetas_runs': metrics['best_thetas_runs'],
                'best_fidelity_runs':metrics['best_fidelity_runs'],
            } 
if True:
    with open("../results/qoc/results_5ghz_td3.json", "w") as outfile: 
        json.dump(data_plot, outfile, cls=CustomEncoder)

# %% [markdown]
# Optionally: Track metrics and parameters in MLflow

# %%
import mlflow
#Metrics resume
metrics_reg= {
    'mean_infidelity_runs': 1- np.mean(metrics['best_fidelity_runs']),
    'std_infidelity_runs': np.std(metrics['best_fidelity_runs']),
        }

params['size_final_dataset'] = y_train.shape[0]


mlflow.set_tracking_uri(uri="http://127.0.0.1:8080")
mlflow.set_experiment("QOC_5GHZ")

with mlflow.start_run(run_name='5GHZ_RL_TD3'):

    mlflow.log_params(params)
    mlflow.log_metrics(metrics_reg)
# Out:
# 2024/09/29 07:49:19 INFO mlflow.tracking._tracking_service.client: 🏃 View run 5GHZ_RL_TD3 at: http://127.0.0.1:8080/#/experiments/880741836310625824/runs/78225c7928a5469181a1e03ad766ab14.
# 2024/09/29 07:49:19 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:8080/#/experiments/880741836310625824.
